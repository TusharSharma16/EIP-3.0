# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 50
l = 10
num_filter = 20
# Out:
# Using TensorFlow backend.

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 25s 0us/step

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input = Input(shape=(img_height, img_width, channel,))

# Layer 1
x01 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input)
x01 = BatchNormalization(name='norm_1')(x01)
x01 = LeakyReLU(alpha=0.1)(x01)
x01 = MaxPooling2D(pool_size=(2, 2))(x01)

# Layer 2
x02 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x01)
x02 = BatchNormalization(name='norm_2')(x02)
x02 = LeakyReLU(alpha=0.1)(x02)
x02 = MaxPooling2D(pool_size=(2, 2))(x02)

# Layer 3
x03 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x02)
x03 = BatchNormalization(name='norm_3')(x03)
x03 = LeakyReLU(alpha=0.1)(x03)

# Layer 4
x04 = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x03)
x04 = BatchNormalization(name='norm_4')(x04)
x04 = LeakyReLU(alpha=0.1)(x04)

# Layer 5
x05 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x04)
x05 = BatchNormalization(name='norm_5')(x05)
x05 = LeakyReLU(alpha=0.1)(x05)
x05 = MaxPooling2D(pool_size=(2, 2))(x05)

# Layer 6
x06 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x05)
x06 = BatchNormalization(name='norm_6')(x06)
x06 = LeakyReLU(alpha=0.1)(x06)

# Layer 7
x07 = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x06)
x07 = BatchNormalization(name='norm_7')(x07)
x07 = LeakyReLU(alpha=0.1)(x07)

# Layer 8
x08 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(x07)
x08 = BatchNormalization(name='norm_8')(x08)
x08 = LeakyReLU(alpha=0.1)(x08)
x08 = MaxPooling2D(pool_size=(2, 2))(x08)

# Layer 9
x09 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x08)
x09 = BatchNormalization(name='norm_9')(x09)
x09 = LeakyReLU(alpha=0.1)(x09)

# Layer 10
x10 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x09)
x10 = BatchNormalization(name='norm_10')(x10)
x10 = LeakyReLU(alpha=0.1)(x10)

# Layer 11
x11 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x10)
x11 = BatchNormalization(name='norm_11')(x11)
x11 = LeakyReLU(alpha=0.1)(x11)

# Layer 12
x12 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x11)
x12 = BatchNormalization(name='norm_12')(x12)
x12 = LeakyReLU(alpha=0.1)(x12)

skip_connection = x12

# Layer 13
x13 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x12)
x13 = BatchNormalization(name='norm_13')(x13)
x13 = LeakyReLU(alpha=0.1)(x13)

# skip_connection = x

x13 = MaxPooling2D(pool_size=(2, 2))(x13)

# Layer 14
x14 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x13)
x14 = BatchNormalization(name='norm_14')(x14)
x14 = LeakyReLU(alpha=0.1)(x14)

# Layer 15
x15 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x14)
x15 = BatchNormalization(name='norm_15')(x14)
x15 = LeakyReLU(alpha=0.1)(x14)

# Layer 16
x16 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x15)
x16 = BatchNormalization(name='norm_16')(x16)
x16 = LeakyReLU(alpha=0.1)(x16)

# Layer 17
x17 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x16)
x17 = BatchNormalization(name='norm_17')(x17)
x17 = LeakyReLU(alpha=0.1)(x17)

# Layer 18
x18 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x17)
x18 = BatchNormalization(name='norm_18')(x18)
x18 = LeakyReLU(alpha=0.1)(x18)

# Layer 19
x19 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x18)
x19 = BatchNormalization(name='norm_19')(x19)
x19 = LeakyReLU(alpha=0.1)(x19)

# Layer 20
x20 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x19)
x20 = BatchNormalization(name='norm_20')(x20)
x20 = LeakyReLU(alpha=0.1)(x20)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x21 = concatenate([skip_connection, x20])

# Layer 22
x22 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x21)
x22 = BatchNormalization(name='norm_22')(x22)
x22 = LeakyReLU(alpha=0.1)(x22)

# Layer 23
x23 = Flatten()(x22)

output = Dense(num_classes, activation='softmax')(x23)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 32)   128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 16, 16, 64)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 16, 16, 64)   256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 64)   0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)     0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 8, 8, 128)    73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 8, 8, 128)    512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 128)    0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 8, 8, 64)     8192        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 8, 8, 64)     256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 8, 64)     0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 8, 8, 128)    73728       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 8, 8, 128)    512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 8, 8, 128)    0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 128)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 4, 4, 256)    294912      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 4, 4, 256)    0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 4, 4, 128)    32768       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 4, 4, 128)    512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 4, 4, 128)    0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 4, 4, 256)    294912      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 4, 4, 256)    0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 256)    0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 2, 2, 512)    1179648     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 2, 2, 512)    2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 2, 2, 512)    0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 2, 2, 256)    0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 2, 2, 512)    0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 2, 2, 256)    0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 2, 2, 512)    0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 1, 1, 512)    0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 1, 1, 1024)   4718592     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 1, 1, 1024)   0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 1, 1, 512)    0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 2, 2, 64)     16384       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 2, 2, 64)     256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 2, 2, 64)     0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 1, 256)    0           leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 1, 1280)   0           lambda_1[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 1, 1, 1024)   11796480    concatenate_1[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_22[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1024)         0           leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           10250       flatten_1[0][0]
# ==================================================================================================
# Total params: 54,734,058
# Trainable params: 54,714,410
# Non-trainable params: 19,648
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 110s 2ms/step - loss: 1.4379 - acc: 0.4801 - val_loss: 1.4704 - val_acc: 0.4893
# Epoch 2/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.9802 - acc: 0.6501 - val_loss: 1.2280 - val_acc: 0.5792
# Epoch 3/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.7802 - acc: 0.7260 - val_loss: 1.3993 - val_acc: 0.5909
# Epoch 4/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.6572 - acc: 0.7721 - val_loss: 1.2046 - val_acc: 0.6325
# Epoch 5/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.5602 - acc: 0.8057 - val_loss: 1.4350 - val_acc: 0.6201
# Epoch 6/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.4859 - acc: 0.8323 - val_loss: 0.8529 - val_acc: 0.7209
# Epoch 7/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.4069 - acc: 0.8585 - val_loss: 0.8871 - val_acc: 0.7330
# Epoch 8/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.3496 - acc: 0.8790 - val_loss: 1.1655 - val_acc: 0.6722
# Epoch 9/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.3010 - acc: 0.8950 - val_loss: 0.8880 - val_acc: 0.7346
# Epoch 10/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.2571 - acc: 0.9103 - val_loss: 1.0484 - val_acc: 0.7170
# Epoch 11/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.2211 - acc: 0.9236 - val_loss: 1.1061 - val_acc: 0.7113
# Epoch 12/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.1844 - acc: 0.9360 - val_loss: 0.9436 - val_acc: 0.7497
# Epoch 13/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.1725 - acc: 0.9402 - val_loss: 1.0591 - val_acc: 0.7341
# Epoch 14/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.1532 - acc: 0.9471 - val_loss: 0.8940 - val_acc: 0.7713
# Epoch 15/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.1216 - acc: 0.9577 - val_loss: 0.8821 - val_acc: 0.7893
# Epoch 16/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.1051 - acc: 0.9624 - val_loss: 1.1283 - val_acc: 0.7529
# Epoch 17/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.1090 - acc: 0.9613 - val_loss: 1.0236 - val_acc: 0.7684
# Epoch 18/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.0942 - acc: 0.9675 - val_loss: 0.9614 - val_acc: 0.7810
# Epoch 19/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0836 - acc: 0.9704 - val_loss: 0.9904 - val_acc: 0.7843
# Epoch 20/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0812 - acc: 0.9716 - val_loss: 1.2902 - val_acc: 0.7334
# Epoch 21/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0774 - acc: 0.9733 - val_loss: 1.1349 - val_acc: 0.7518
# Epoch 22/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0734 - acc: 0.9743 - val_loss: 1.2230 - val_acc: 0.7723
# Epoch 23/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0692 - acc: 0.9757 - val_loss: 1.1826 - val_acc: 0.7673
# Epoch 24/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0655 - acc: 0.9770 - val_loss: 1.1361 - val_acc: 0.7689
# Epoch 25/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0724 - acc: 0.9753 - val_loss: 0.9711 - val_acc: 0.7942
# Epoch 26/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0663 - acc: 0.9783 - val_loss: 1.2096 - val_acc: 0.7410
# Epoch 27/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0567 - acc: 0.9804 - val_loss: 1.1505 - val_acc: 0.7682
# Epoch 28/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0512 - acc: 0.9826 - val_loss: 1.3217 - val_acc: 0.7428
# Epoch 29/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0478 - acc: 0.9835 - val_loss: 1.1381 - val_acc: 0.7714
# Epoch 30/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0495 - acc: 0.9829 - val_loss: 1.0915 - val_acc: 0.7769
# Epoch 31/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0502 - acc: 0.9827 - val_loss: 1.2212 - val_acc: 0.7612
# Epoch 32/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0543 - acc: 0.9816 - val_loss: 1.2108 - val_acc: 0.7633
# Epoch 33/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0398 - acc: 0.9867 - val_loss: 1.4987 - val_acc: 0.7438
# Epoch 34/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.0446 - acc: 0.9848 - val_loss: 1.0964 - val_acc: 0.7801
# Epoch 35/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.0413 - acc: 0.9855 - val_loss: 1.1314 - val_acc: 0.7757
# Epoch 36/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0408 - acc: 0.9861 - val_loss: 1.2452 - val_acc: 0.7690
# Epoch 37/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0553 - acc: 0.9815 - val_loss: 1.0696 - val_acc: 0.7900
# Epoch 38/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0377 - acc: 0.9877 - val_loss: 1.3172 - val_acc: 0.7492
# Epoch 39/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0402 - acc: 0.9867 - val_loss: 1.0685 - val_acc: 0.7914
# Epoch 40/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0367 - acc: 0.9877 - val_loss: 1.2622 - val_acc: 0.7650
# Epoch 41/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0366 - acc: 0.9880 - val_loss: 1.2776 - val_acc: 0.7629
# Epoch 42/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0336 - acc: 0.9884 - val_loss: 1.4696 - val_acc: 0.7315
# Epoch 43/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0340 - acc: 0.9883 - val_loss: 1.0847 - val_acc: 0.7895
# Epoch 44/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0336 - acc: 0.9884 - val_loss: 1.1363 - val_acc: 0.7777
# Epoch 45/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0308 - acc: 0.9895 - val_loss: 1.0984 - val_acc: 0.7852
# Epoch 46/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0308 - acc: 0.9891 - val_loss: 1.1357 - val_acc: 0.7875
# Epoch 47/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0260 - acc: 0.9912 - val_loss: 1.1892 - val_acc: 0.7935
# Epoch 48/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0298 - acc: 0.9900 - val_loss: 1.1529 - val_acc: 0.7823
# Epoch 49/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.0338 - acc: 0.9884 - val_loss: 1.2378 - val_acc: 0.7736
# Epoch 50/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0280 - acc: 0.9907 - val_loss: 1.3456 - val_acc: 0.7675

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 10s 973us/step
# Test loss: 1.3455836562156678
# Test accuracy: 0.7675
# Saved the model to disk

# %%
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
from google.colab import files

files.download('Yolo_Basic_model.h5')
# Out:
# Saved the model to disk
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-7fd61af6c08d> in <module>()
#       3 from google.colab import files
#       4
# ----> 5 files.download('Yolo_Basic_model.h5')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     142       raise OSError(msg)
#     143     else:
# --> 144       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     145
#     146   started = _threading.Event()
#
# FileNotFoundError: Cannot find file: Yolo_Basic_model.h5
